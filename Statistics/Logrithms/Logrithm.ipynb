# %% [markdown]
# ### Goal
# The goal of this exercise is to demonstrate the usefullness of log function

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\gjrah\Documents\Data Science\Data_Science\Statistics\Datasets\Logrithms\revenue.csv")

# %%
df
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6
# 5        Vedanta     11.3

# %%
df.plot(x='company',y='revenue',kind='bar',xlabel='Company',ylabel='Revenue')
# Out:
# <Axes: xlabel='Company', ylabel='Revenue'>

# %% [markdown]
# - We can observe that Amazon takes up most of the space
# - We can use log function on y to normalise the distribtion

# %%
df.plot(x='company',y='revenue',xlabel='Company',ylabel='Revenue',kind='bar',logy=True)
# Out:
# <Axes: xlabel='Company', ylabel='Revenue'>

# %% [markdown]
# - Conclusion: We have normalized the graph by applying the logrithm (log 10) on Y axis
